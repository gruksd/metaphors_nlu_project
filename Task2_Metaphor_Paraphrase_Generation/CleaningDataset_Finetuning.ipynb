# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
import pandas as pd

data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/trainingdata_paraphrases.csv',sep=',')

# %%
data
# Out:
#        Unnamed: 0                                sentence paraphrase_word
# 0               0                    i ate *the* cheese .            some
# 1               1                   i *eat* some cheese .             ate
# 2               2                   i ate *some* cheese .             the
# 3               3                   i *ate* some cheese .             eat
# 4               4                        it *'s* monday .              is
# ...           ...                                     ...             ...
# 62316       62595   she watched him *drawing* a picture .            draw
# 62317       62596  what 's your favorite *horror* movie ?           scary
# 62318       62597   what 's your favorite *scary* movie ?          horror
# 62319       62598                    *globalise* or die .       globalize
# 62320       62599                    *globalize* or die .       globalise
#
# [62321 rows x 3 columns]

# %%
for index, row in data.iterrows():
  if row["sentence"].count("*") > 2:
    data.drop(index, inplace=True)
  else:
    pass

# %%
data
# Out:
#        Unnamed: 0                                sentence paraphrase_word
# 0               0                    i ate *the* cheese .            some
# 1               1                   i *eat* some cheese .             ate
# 2               2                   i ate *some* cheese .             the
# 3               3                   i *ate* some cheese .             eat
# 4               4                        it *'s* monday .              is
# ...           ...                                     ...             ...
# 62316       62595   she watched him *drawing* a picture .            draw
# 62317       62596  what 's your favorite *horror* movie ?           scary
# 62318       62597   what 's your favorite *scary* movie ?          horror
# 62319       62598                    *globalise* or die .       globalize
# 62320       62599                    *globalize* or die .       globalise
#
# [61590 rows x 3 columns]

# %%
import numpy as np

for index, row in data.iterrows():
  if row["paraphrase_word"] == "," or row["paraphrase_word"] == "":
    data.drop(index, inplace=True)
  else:
    pass

# %%
data
# Out:
#        Unnamed: 0                                sentence paraphrase_word
# 0               0                    i ate *the* cheese .            some
# 1               1                   i *eat* some cheese .             ate
# 2               2                   i ate *some* cheese .             the
# 3               3                   i *ate* some cheese .             eat
# 4               4                        it *'s* monday .              is
# ...           ...                                     ...             ...
# 62316       62595   she watched him *drawing* a picture .            draw
# 62317       62596  what 's your favorite *horror* movie ?           scary
# 62318       62597   what 's your favorite *scary* movie ?          horror
# 62319       62598                    *globalise* or die .       globalize
# 62320       62599                    *globalize* or die .       globalise
#
# [61567 rows x 3 columns]

# %%
for index, row in data.iterrows():
  if pd.isnull(row["paraphrase_word"]) == True:
    data.drop(index, inplace=True)
  else:
    pass

# %%
data
# Out:
#        Unnamed: 0                                sentence paraphrase_word
# 0               0                    i ate *the* cheese .            some
# 1               1                   i *eat* some cheese .             ate
# 2               2                   i ate *some* cheese .             the
# 3               3                   i *ate* some cheese .             eat
# 4               4                        it *'s* monday .              is
# ...           ...                                     ...             ...
# 62316       62595   she watched him *drawing* a picture .            draw
# 62317       62596  what 's your favorite *horror* movie ?           scary
# 62318       62597   what 's your favorite *scary* movie ?          horror
# 62319       62598                    *globalise* or die .       globalize
# 62320       62599                    *globalize* or die .       globalise
#
# [61566 rows x 3 columns]

# %%
data.loc[[34864]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-587e631c4814> in <cell line: 1>()
# ----> 1 data.loc[[34864]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1101
#    1102             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103             return self._getitem_axis(maybe_callable, axis=axis)
#    1104
#    1105     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1330                     raise ValueError("Cannot index with multidimensional key")
#    1331
# -> 1332                 return self._getitem_iterable(key, axis=axis)
#    1333
#    1334             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
# ...

# %%
data.to_csv('trainingdata_paraphrases_cleaned.csv')
# !cp trainingdata_paraphrases_cleaned.csv "/content/drive/MyDrive/Colab Notebooks/"
